# %%
from CNNEevaluation import CatImageClassifier

import numpy as np

# %%
excel_path = 'File_cats.xlsx'
image_dir = './images/'

# %%
classifier = CatImageClassifier(excel_path, image_dir)
classifier.build_model()
classifier.train_model()
classifier.evaluate_model()
classifier.model.save('cat_classifier_model.h5')
np.save('label_encoder_classes.npy', classifier.label_encoder.classes_)
# Out:
# Epoch 1/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 0.2432 - loss: 2.3060 - val_accuracy: 0.2000 - val_loss: 2.1146
# Epoch 2/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2870 - loss: 3.4950 - val_accuracy: 0.2400 - val_loss: 1.7504
# Epoch 3/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3006 - loss: 2.0208 - val_accuracy: 0.3600 - val_loss: 1.7541
# Epoch 4/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.2766 - loss: 1.7371 - val_accuracy: 0.3200 - val_loss: 1.7577
# Epoch 5/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3872 - loss: 1.7417 - val_accuracy: 0.2800 - val_loss: 1.7574
# Epoch 6/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3998 - loss: 1.7438 - val_accuracy: 0.3200 - val_loss: 1.7556
# Epoch 7/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.4102 - loss: 1.7400 - val_accuracy: 0.3200 - val_loss: 1.7501
# Epoch 8/500
# ...

# %%
new_image_path = './images/Prova1.png'
predicted_cat_name = classifier.predict_cat(new_image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
print(f'The predicted cat name is: {predicted_cat_name}')
# Out:
# The predicted cat name is: Gina

# %%
classifier.plot_predictions(num_samples=5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
